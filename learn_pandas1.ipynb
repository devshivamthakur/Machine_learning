# %%
import pandas as pd

# %%
df=pd.read_csv("../sampledata/survey_results_public.csv")

# %%
df["Respondent"]
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 64456    64858
# 64457    64867
# 64458    64898
# 64459    64925
# 64460    65112
# Name: Respondent, Length: 64461, dtype: int64

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df["Age"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
#          ...
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
df["Age"]>19
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Age, Length: 64461, dtype: bool

# %%
df2=df
df2["Country"]
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %% [markdown]
# Filtering data

# %% [raw]
# ji

# %% [markdown]
# <B>Filtering data </B>

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df=pd.read_csv("../sampledata/survey_results_public.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#find out all hobbyist , workweekhrs whose age is greate than 10
df2=df.loc[df["Age"]>10,["Hobbyist","WorkWeekHrs"]]

# %%
df2.head()
# Out:
#   Hobbyist  WorkWeekHrs
# 3      Yes         40.0
# 4      Yes          NaN
# 7      Yes         39.0
# 8       No         50.0
# 9      Yes         36.0

# %%
#find out all mainbranch of  United Kingdom
df.loc[df["Country"]=="United Kingdom",["MainBranch"]]
# Out:
#                            MainBranch
# 1      I am a developer by profession
# 9      I am a developer by profession
# 10     I am a developer by profession
# 15     I am a developer by profession
# 29     I am a developer by profession
# ...                               ...
# 64247                             NaN
# 64253                             NaN
# 64279                             NaN
# 64422                             NaN
# 64432                             NaN
#
# [3896 rows x 1 columns]

# %%
#find out all survey from uk and us
df[df["Country"].isin(["United Kingdom","United State"])]

# %%
#find out shape (row,column) all survey from uk and us
df[df["Country"].isin(["United Kingdom","United State"])].shape
# Out:
# (3896, 61)

# %%
#find out 10 survey from uk and us
mydf=df[df["Country"].isin(["United Kingdom","United State"])]
mydf.head(n=10)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 1            2                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# 15          16                     I am a developer by profession      Yes
# 29          30                     I am a developer by profession      Yes
# 35          36  I am not primarily a developer, but I write co...      Yes
# 38          39  I am not primarily a developer, but I write co...      Yes
# 46          47                     I am a developer by profession      Yes
# 51          52                     I am a developer by profession       No
# 61          62             I am a student who is learning to code       No
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
mydf
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 1               2  I am a developer by profession       No   NaN         19
# 9              10  I am a developer by profession      Yes  22.0         14
# 10             11  I am a developer by profession      Yes  23.0         13
# 15             16  I am a developer by profession      Yes  45.0          8
# 29             30  I am a developer by profession      Yes   NaN         14
# ...           ...                             ...      ...   ...        ...
# 64247       22677                             NaN      Yes   NaN         25
# 64253       24973                             NaN      Yes  21.0         12
# 64279       31525                             NaN      Yes  67.0         35
# 64422       59638                             NaN      Yes  23.0         10
# 64432       61490                             NaN      Yes   NaN         14
#
# ...

# %%
# find out all the webframeworkedwith and wrokweekhrs from survey where age >10 and country is Germany
df2=df.loc[(df["Age"]>19)&(df["Country"].isin(["Germany"])) ,["WebframeWorkedWith","WorkWeekHrs"]]

# %%
df2
# Out:
#            WebframeWorkedWith  WorkWeekHrs
# 22                        NaN         40.0
# 23                        NaN         42.0
# 33            Angular;Express          NaN
# 104      ASP.NET;ASP.NET Core         40.0
# 109    Angular;Express;jQuery          NaN
# ...                       ...          ...
# 61917           jQuery;Vue.js         40.0
# 64234     Django;Flask;jQuery          NaN
# 64239                   Flask          NaN
# 64277                     NaN          NaN
# 64336                     NaN          NaN
#
# [2888 rows x 2 columns]

# %%
df2.head( n=10)
# Out:
#          WebframeWorkedWith  WorkWeekHrs
# 22                      NaN         40.0
# 23                      NaN         42.0
# 33          Angular;Express          NaN
# 104    ASP.NET;ASP.NET Core         40.0
# 109  Angular;Express;jQuery          NaN
# 118                 Laravel         40.0
# 135                     NaN         40.0
# 146           Ruby on Rails         40.0
# 164                     NaN         40.0
# 178                     NaN         45.0

# %%
# reset index but not change original data
df2.reset_index()
# Out:
#       index      WebframeWorkedWith  WorkWeekHrs
# 0        22                     NaN         40.0
# 1        23                     NaN         42.0
# 2        33         Angular;Express          NaN
# 3       104    ASP.NET;ASP.NET Core         40.0
# 4       109  Angular;Express;jQuery          NaN
# ...     ...                     ...          ...
# 2883  61917           jQuery;Vue.js         40.0
# 2884  64234     Django;Flask;jQuery          NaN
# 2885  64239                   Flask          NaN
# 2886  64277                     NaN          NaN
# 2887  64336                     NaN          NaN
#
# [2888 rows x 3 columns]

# %%
# its reset index and remove old index by using inplace=true,drop=true
df2.reset_index(inplace=True,drop=True)

# %%
df2
# Out:
#           WebframeWorkedWith  WorkWeekHrs
# 0                        NaN         40.0
# 1                        NaN         42.0
# 2            Angular;Express          NaN
# 3       ASP.NET;ASP.NET Core         40.0
# 4     Angular;Express;jQuery          NaN
# ...                      ...          ...
# 2883           jQuery;Vue.js         40.0
# 2884     Django;Flask;jQuery          NaN
# 2885                   Flask          NaN
# 2886                     NaN          NaN
# 2887                     NaN          NaN
#
# [2888 rows x 2 columns]

# %% [markdown]
# <B> Sorting </B>

# %%
df.sort_values(by=["Country"],ascending=True).head(5)
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 8599         8631  I am a student who is learning to code       No   NaN
# 24908       25001          I am a developer by profession       No   NaN
# 57044       58171  I am a student who is learning to code      Yes  23.0
# 41950       42668          I am a developer by profession      Yes   NaN
# 50469       51509          I am a developer by profession       No  28.0
#
#                  Age1stCode CompFreq  CompTotal  ConvertedComp      Country  \
# 8599                     19      NaN        NaN            NaN  Afghanistan
# 24908  Younger than 5 years   Weekly        NaN            NaN  Afghanistan
# 57044                    18      NaN        NaN            NaN  Afghanistan
# 41950                   NaN      NaN        NaN            NaN  Afghanistan
# 50469                    19  Monthly   130000.0        20220.0  Afghanistan
#
# ...

# %% [markdown]
# <B>add Column in data frame

# %%
import numpy as np

# %%
df["Age_status"]=np.where(df["Age"]<=18,"fresher Developer", (np.where(df["Age"]<35, 'Experience Developer', 'Senior Developer')))

# %%
df["Age_status"]
# Out:
# 0            Senior Developer
# 1            Senior Developer
# 2            Senior Developer
# 3        Experience Developer
# 4        Experience Developer
#                  ...
# 64456        Senior Developer
# 64457        Senior Developer
# 64458        Senior Developer
# 64459        Senior Developer
# 64460        Senior Developer
# Name: Age_status, Length: 64461, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=64461, step=1)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6828/1703117804.py in <module>
# ----> 1 df
#       2
#
# NameError: name 'df' is not defined
